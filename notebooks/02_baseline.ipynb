# %% [markdown]
# # 02. Baseline Model
# Train a very simple baseline to ensure the pipeline works end-to-end.

# %%
import pandas as pd
from src.config import load_config
from src.split import make_splits
from src.train import cross_validate
from src.metrics import get_metric

cfg = load_config()
# df = pd.read_csv(cfg.data.train_path)
# splits = make_splits(df, strategy='kfold')
# res = cross_validate(df, cfg.task.target_column, splits, 'dummy', get_metric('rmse'))
