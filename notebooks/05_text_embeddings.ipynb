# %% [markdown]
# # 05. Text Embeddings
# Compute robust embeddings for text data and cache them.

# %%
from src.embeddings import TextEmbedder, EmbeddingCache, EmbeddingManifest
# embedder = TextEmbedder('sentence-transformers/all-MiniLM-L6-v2')
# embs = embedder.fit_transform(df['text'])
