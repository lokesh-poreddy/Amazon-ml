# %% [markdown]
# # 06. Ensemble
# Blend multiple models to maximize metric.

# %%
import numpy as np
from src.ensemble import score_weighted_selection, optimise_weights, OOFCandidate

# candidates = [OOFCandidate('lgbm', preds, score), ...]
# diverse = score_weighted_selection(candidates, metric, y_true)
# weights, best_score = optimise_weights(diverse, y_true, metric)
