# %% [markdown]
# # 00. Schema Audit
# Identify the competition datasets and validate their schema structure.

# %%
import pandas as pd
from src.config import load_config
from src.data import discover_files

cfg = load_config()
discovered = discover_files('data/raw')
print(discovered)
