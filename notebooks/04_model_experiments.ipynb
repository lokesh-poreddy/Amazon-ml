# %% [markdown]
# # 04. Model Experiments
# Train LightGBM, XGBoost, and CatBoost, and log results.

# %%
import pandas as pd
from src.config import load_config
from src.train import cross_validate

cfg = load_config()
# res_lgb = cross_validate(df, target, splits, 'lgbm', metric)
# res_xgb = cross_validate(df, target, splits, 'xgb', metric)
