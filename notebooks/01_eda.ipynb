# %% [markdown]
# # 01. Exploratory Data Analysis
# Analyze distributions, missing values, and target correlations.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from src.config import load_config

cfg = load_config()
# df = pd.read_csv(cfg.data.train_path)
