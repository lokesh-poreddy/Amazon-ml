# %% [markdown]
# # 07. Final Submission
# Train on full data, predict on test, validate, and write final CSV.

# %%
import pandas as pd
from src.train import train_final_model
from src.submission import create_submission_df, write_submission
from src.utils import check_final_package

# model = train_final_model(train_df, target, 'lgbm', n_estimators=...)
# preds = model.predict(test_df)
# write_submission(...)
