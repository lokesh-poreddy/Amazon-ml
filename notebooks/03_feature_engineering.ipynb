# %% [markdown]
# # 03. Feature Engineering
# Develop FeaturePipeline and analyze feature importances.

# %%
import pandas as pd
from src.config import load_config
from src.features import FeaturePipeline

cfg = load_config()
# pipe = FeaturePipeline(numeric_cols=[...])
